# %% [markdown]
# # Tutorial 3 python operators

# %% [markdown]
#  # Python Operators
# 1 Logical
#
# 2 Equality
#
# 3 Comparision
#
# 4 Arthmetic

# %% [markdown]
#  # 4.1. logical Operators
# in pythone follwing keywords are used fro boolean operatins-
# keywords  meanig
# * not     unary negation
# * and     conditional AND
# * or      Coditional OR

# %% [markdown]
# EXAMPLES:

# %%
type(False)
# Out:
# bool

# %%
type(True)
# Out:
# bool

# %%
bool(1)
# Out:
# True

# %%
a = True
b = False

# %%
True and False
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
age = int(input("Enter the age"))
if age>18 and age<=35:
    print("mid age")
# Out:
# Enter the age 19
# mid age

# %%
age = int(input("Enter the age"))
if age<18 or age>=35:
    print("Successful excution")
# Out:
# Enter the age 16
# Successful excution

# %% [markdown]
# # Equalitly Operators
#
# Following operations are present in python for equlity check operation
# |Operators | Meaning |
# |-|-|
# |**is**|***a is b*** returns true if variable/identifiers a and b *points to the same object*|
# |**is not**|***a is not b*** returns true if variable/identifiers a and b *points to thedifferent object*|
# |**==**|a == b returns true if variable/identifiers a and b has same value|
# |**!=**|***a !=b*** returns true if variable/identifiers a and b has different value|

# %%
a = "Atul"
b = "Atul"
a==b
# Out:
# True

# %%
a = "Atul"
b = "Atul More"
a==b
# Out:
# False

# %%
age = int(input("Enter th age"))
if age == 18:
    
    print("you are in the teenager age")
# Out:
# Enter th age 18
# you are in the teenager age

# %%
a ="Atul"
b = "Atul"
print(id(a))
print(id(b))
# Out:
# 2526319788416
# 2526319788416

# %%
a is b
# Out:
# True

# %%
a == b
# Out:
# True

# %%
a != b
# Out:
# False

# %%
a is not b
# Out:
# False

# %%
lat = [1,2,3,4]
lst = [1,2,3,4]
print(id(lst))
print(id(lst))
# Out:
# 2526330417088
# 2526330417088

# %%
"Atul" != "Atul more"
# Out:
# True

# %% [markdown]
# # comparison operators
# |Operation|Meaning|
# |:-:|:-:|
# | **<**|less than
# | **<=**|less than or equal tol|
# | **>** | greater than|
# | **>=** | greater than or equal to|

# %%
Marks = float(input("Enter the marks"))
if Marks>=35:
    print("Pass")
    if Marks >=50 and Marks<=70:
        print("First")
elif Marks<35:
    print("Fail")
# Out:
# Enter the marks 60
# Pass
# First

# %% [markdown]
#  ## Arithmetic Operators
# |Operation|Meaning |
# |:-:|:-:|
# |**+**|addition|
# |**-**|subtraction|
# |**\***|multiplication|
# |**/**|true division|
# |**//**|integer division|
# |**%**|the modulo operator|

# %%
23 + 30
# Out:
# 53

# %%
34 - 15
# Out:
# 19

# %%
12 * 2
# Out:
# 24

# %%
10 / 4
# Out:
# 2.5

# %%
10//4
# Out:
# 2

# %%
10 // 2
# Out:
# 5

# %%
10 % 2
# Out:
# 0

# %%
def is_leap(year):
    leap = False
    
    # Write your logic here
    
    return leap

year = int(input())
print(is_leap(year))
